# %% [markdown]
# Author: [Vinícius Rios Fuck](https://www.linkedin.com/in/viniciusriosfuck/)
#
# Data: 21 June 2020
#
# Institution: [Codenation](https://codenation.dev/)

# %%
# ![alt text](https://content.linkedin.com/content/dam/me/business/en-us/amp/brand-site/v2/bg/LI-Bug.svg.original.svg "Title")
# https://content.linkedin.com/content/dam/me/business/en-us/amp/brand-site/v2/bg/LI-Logo.svg.original.svg

# %% [markdown]
# # Challenge 1
#
# For this challenge, we work with the [Black Friday](https://www.kaggle.com/mehdidag/black-friday) data set.
# This one gathers data from purchases in an unidentified retail store.
#
# We use to practice some data exploratory skills with [Pandas](https://pandas.pydata.org/).
#
# > Obs.: If you want to submit this challenge, you are required to please, keep the answer function's names.

# %% [markdown]
# ## Analysis _Set up_

# %% [markdown]
# We have to perform an analysis.
# In order to that if we use only raw Python, we won't have as many tools as if we load some useful libraries.
#
# > So, as that's not cheat, we don't need to reinvent the wheel.
# >
# > Let's use and abuse from the well efficiently already programmed functions.
#
# One library already programmed with a series of methods to analyse data in a table form is Pandas.
# Pandas was built on [Numpy](https://numpy.org/) basis.
#
# Good explained!
# I don't know what Pandas is, and you say that Pandas is built on Numpy.
# I don't need to say that I don't know Numpy neither, do I?
#
# Numpy is a library that has a lot of numerical methods to deal with array data.
#
# Enough with the talk. We don't need to worry about it.  Only keep in mind:
#     1. Pandas: tools for tabled data
#     2. Numpy: numerical manipulation
#
# It's a common practice to load the libraries as aliases, that is with a different and preferable short name.

# %% [markdown]
# ## Useful links
#
# 1. [Python](https://www.python.org/)
#     1. [Docs](https://docs.python.org/3/)
#     2. [Tutorial](https://docs.python.org/3/tutorial/)
# 2. [Pandas](https://pandas.pydata.org/)
#     1. [Docs](https://pandas.pydata.org/pandas-docs/stable/)
#     2. [10 min](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html)
#     3. [Basics](https://pandas.pydata.org/pandas-docs/stable/getting_started/basics.html)
# 3. [Numpy](https://numpy.org/)
#     1. [Docs](https://numpy.org/doc/stable/)
#     2. [Quickstart](https://numpy.org/doc/stable/user/quickstart.html)
#     3. [Basics](https://numpy.org/doc/stable/user/basics.html)
# 4. [PEP 0 -- Index of Python Enhancement Proposals (PEPs)](https://www.python.org/dev/peps/)
#     1. [PEP 8 -- Style Guide for Python Code](https://www.python.org/dev/peps/pep-0008/)
#     2. [PEP 20 -- The Zen of Python](https://www.python.org/dev/peps/pep-0020/)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The following web hyperlink address contains the file for the analysis

# %%
url = "https://codenation-challenges.s3-us-west-1.amazonaws.com/data-science-0/black_friday.csv"

# %% [markdown]
# One can observe that the data has a `.csv` extension.
#
# CSV stands for
# [<b>C</b>omma
# <b>S</b>eparated
# <b>V</b>alue](https://en.wikipedia.org/wiki/Comma-separated_values).
#
# This is a very common file type for datasets, because it stores more (data) in less (memory size).

# %% [markdown]
# In this particularly case the raw data are like:
# ```
# col1,col2,col3
# 1,2,3
# ```
# That's the default structure, so don't need to specify separators or indexes.

# %% [markdown]
# We have different options to load a file. You can access the file directly via the provided link

# %%
df = pd.read_csv(url)

# %% [markdown]
# Another possible option is to retrieve the file locally from the same working directory in which you find yourself

# %%
df = pd.read_csv("black_friday.csv")

# %% [markdown]
# It's a common practice when one works with a dataframe to name it as df.
# Such choice provides some advantages as:
#     1. make some code chunks usable for others data-sets
#     2. make the calls more compact

# %% [markdown]
# If you have payed enough attention you will see that we create a [dataframe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html?) object called `df`.
#
# Within you can call all the functions of the Pandas library.
#
# The first one used was [`read_csv`](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html?) which enables us to get the data in a well structured table form.

# %% [markdown]
# ## Seeing the data

# %% [markdown]
# ### Directly way
# Let's look at the data.

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %% [markdown]
# This is the easiest and intuitively way, with a lot of information on it.
#
# > If I scroll the rolling bar on the right side.
#
# Please don't be so extremely right. The internal one.
#
# > I see the first 30 lines.
#
# So it works as (a not black) mirror and we see the last 30 lines.
#
# Oh yeah. It seems to be well structured. Less work for us then.
#
# And nice, we see that we have __537577__ rows × __12__ columns

# %% [markdown]
# But if you are a different kind of person, one that likes to go by pieces as Jack The Ripper ...
#
# ### Jack the Ripper's way
#
# #### [Head](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html)
#
# We can start by the start.
# So look at the first lines.

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %% [markdown]
# When one calls a function without arguments, in this case `()`, we use the default values.
# By default the [`head`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html) function displays the first 5 lines, rows, records or any other suitable synonym that pleases you.
#
# Nevertheless, you can display as many rows you want by passing the desired number as argument.
# For example, 2.

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %% [markdown]
# #### [Tail](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html)
#
# We can check the end of the data as well, with the [`tail`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html) function.
# It behaves similarly to [`head`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html), but shows the last lines instead.

# %%
df.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 537572                 2.0                 NaN     11664
# ...

# %%
df.tail(2)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 537575                 NaN                 NaN      7172
# 537576                 8.0                 NaN      6875

# %% [markdown]
# #### Rows number
#
# Ok, so the data seems to have 537,576 rows. And...
#
# > Noooooooooooooooooooo!
#
# Wait...
#
# Ok. I'm waiting ...
#
# Python starts at 0. As you can see on the `head` calls.

# %%
df.head(1)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370

# %% [markdown]
# Oh! I got it!
#
# So 537,577 rows.
#
# > This is a common mistake, please remember that.

# %% [markdown]
# #### Columns number
#
# Ok now start to count how many columns do we have.
#
# We count the first one? I don't know. Oh.
#
# > So User_ID: 1 or 2; Product_ID: 2 or 3; ... Product_Category_2: n or n+1, ...
#
# Oh I have to scroll the rolling bar and I forgot the numbers.
#
# > Maybe use some already programmed functions?
#
# Yeah, seems a good idea.

# %% [markdown]
# _Sidenote_
#
# No, we don't count the first one.
#
# It's an index's column autocreated by Pandas in order to ease the manipulation.
#
# It's generally a good idea to have an unique ID in the first column.
#
# If you see the first two rows

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %% [markdown]
# We see that the User_ID is not unique for them, that means that the same user has made more than one purchase.

# %% [markdown]
# #### [Shape](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html)
#
# If you want to see the shape of the data.
#
# Well surprise. Call [`shape`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html) .

# %%
df.shape
# Out:
# (537577, 12)

# %% [markdown]
# So the data still has __537577__ rows × __12__ columns.
#
# That's really good, because we didn't do nothing on the data.
#
# Good that has the same amount as the first approach.
#
# And remark:
# > You are strongly recommended to __keep the data as it is__.
#
# We can create some extra variables in order to manipulate, but is always a good practice to keep the original data somewhere.
#
# And that's a advantage of an object oriented language we can do a lot of operations on it, without altering the referred object.
#
# Let's continue seeing the data

# %% [markdown]
# ### More information

# %% [markdown]
# #### Direct way
# To check for ['info'](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html)  we can perhaps call ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
# User_ID                       537577 non-null int64
# Product_ID                    537577 non-null object
# Gender                        537577 non-null object
# Age                           537577 non-null object
# Occupation                    537577 non-null int64
# City_Category                 537577 non-null object
# Stay_In_Current_City_Years    537577 non-null object
# Marital_Status                537577 non-null int64
# Product_Category_1            537577 non-null int64
# Product_Category_2            370591 non-null float64
# Product_Category_3            164278 non-null float64
# Purchase                      537577 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 49.2+ MB

# %% [markdown]
# 1. Good `df` is a Pandas object. It worked.
# 2. Oh, cool ... another synonym for rows: entries. And you tricky Python, at least you are sincere enough to say that you start indeed on 0.
# 3. So we have **12** columns (we've already known that).
# 4. **537,577** I've know this by heart by now, `non-null` that's good, [`int64`](https://docs.python.org/3/library/stdtypes.html#numeric-types-int-float-complex)???
# 5. [`object`](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html)???
# 6. **370,591** that's not 537,577. Oh nooooooooooo. We were so good. whyyyyy we don't have data. No. No. No.
# 7. Are you kidding me **164,278**, we have less data than before???
# 8. [`float64`](https://docs.python.org/3/library/stdtypes.html#numeric-types-int-float-complex)???
# 9. [`dtypes`](https://pandas.pydata.org/docs/getting_started/basics.html#basics-dtypes) and again those names with numbers in parenthesis. Oh numbers, let's sum them up... 2+5+5 = **12**. I already seen this columns before.
# 10. **49.2+** MB??? But we manipulate so quickly. The team that made Pandas and Numpy are experts. I will use their libraries.

# %% [markdown]
# [__Types__](https://docs.python.org/3/library/stdtypes.html)
#
# So we have a lot of [types](https://docs.python.org/3/library/stdtypes.html).
#
# Different from other programming languages we can have distinct [types](https://docs.python.org/3/library/stdtypes.html) together.
#
# * [`int64`](https://docs.python.org/3/library/stdtypes.html#numeric-types-int-float-complex) refers to integer (0,1,2,...) of 64 bits
# * [`float64`](https://docs.python.org/3/library/stdtypes.html#numeric-types-int-float-complex) corresponds to float (0.0001, -0.002577894, ...) of 64 bits
# * [`object`](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html) in this case refers to a form to store [text data](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html). We will be back to explain this better. Another one is by strings

# %% [markdown]
# All these information can be retrieve piecewise as well.
#
# Please don't repeat the same joke, unless it's for separate the text.

# %% [markdown]
# #### Jack The Ripper's Way
#
# __Columns names__
#
# It's usually useful to see concisely the columns' names that we are working on

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %% [markdown]
# Oh nice. We start to ask ourselves, what means this object hidden on dtype.
#
# We will try to inspect the type from this.

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# No way. It works ...
#
# So the df.columns refers to a Pandas index. That makes sense.

# %% [markdown]
# #### A little digression
# Now we are the type master and could inquire the type from everything. Yeah.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Good our dataframe is a dataframe.
#
# We think we are kidding? Everything.

# %%
type(pd)
# Out:
# module

# %%
type(np)
# Out:
# module

# %% [markdown]
# Oh! The pd and np are modules.

# %%
pd
# Out:
# <module 'pandas' from 'c:\\users\\fuck\\pycharmprojects\\codenation\\venv\\lib\\site-packages\\pandas\\__init__.py'>

# %%
pd?

# %% [markdown]
# No way, we have a help, when we don't know something.

# %%
df.head?

# %% [markdown]
# Seriously? Now we are the ? master as well

# %%
type(url)
# Out:
# str

# %% [markdown]
# The typed url's text is a string. It makes sense.

# %%
str?

# %%
type(df.head())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Oh yeah. That makes sense, because the output from head() keeps the same well structured form from the df.

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
type(df.shape)
# Out:
# tuple

# %% [markdown]
# A tuple? What's a tuple?

# %%
tuple?

# %% [markdown]
# Ok, ok. Basically is a thing that has things on it. And you can't change it.
#
# More concisely, if you see an object between parentheses is a `(tuple)`

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.shape[0]
# Out:
# 537577

# %% [markdown]
# Oh we can access it, so you can change it, let's prove

# %%
#df.shape[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-90554c93d5f7> in <module>
# ----> 1 df.shape[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Yeah, the documentation were right. Duh?
#
# But if we would desire to change something...
#
# We could choose another class. For example list.
#
# We already know what to do

# %%
list?

# %% [markdown]
# Before, we have talked a lot of objects, so

# %%
object?

# %% [markdown]
# The most base type. That makes sense on an oriented programming language.

# %%
int64?
# Out:
# Object `int64` not found.

# %% [markdown]
# Ok, it doesn't work always. But keep that in mind. It can bring a lot of insights to you.
#
# Perhaps a little bit different

# %%
int?

# %%
float64?
# Out:
# Object `float64` not found.

# %% [markdown]
# We are insistent. Hm. Don't get upset.

# %%
float?

# %%
type(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
# User_ID                       537577 non-null int64
# Product_ID                    537577 non-null object
# Gender                        537577 non-null object
# Age                           537577 non-null object
# Occupation                    537577 non-null int64
# City_Category                 537577 non-null object
# Stay_In_Current_City_Years    537577 non-null object
# Marital_Status                537577 non-null int64
# Product_Category_1            537577 non-null int64
# Product_Category_2            370591 non-null float64
# Product_Category_3            164278 non-null float64
# Purchase                      537577 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 49.2+ MB
# NoneType

# %% [markdown]
# Whaaaaaaaat?
#
# df.info() has no type.

# %%
df.info?

# %% [markdown]
# Ok. It's a method.
#
# Enough is enough.

# %% [markdown]
# #### Jack the Ripper piece 2
# Please stop with that.
#
# One way to only see the data type is

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df.dtypes?

# %% [markdown]
# So, an object, but which one?

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
Series?
# Out:
# Object `Series` not found.

# %% [markdown]
# Oh yeah it was not built-in on Python. Perhaps

# %%
pd.Series?

# %% [markdown]
# But it seems as a dataframe, no? Yeah indeed. But one-dimensional one.

# %%
pd.DataFrame?

# %% [markdown]
# Ok so the types are these, and the types are those, but how many? Lets count them ...

# %%
df.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# dtype: int64

# %% [markdown]
# In total we have the well known column's number

# %%
df.dtypes.count()
# Out:
# 12

# %% [markdown]
# We can try to coerce the object data to become something else

# %%
df.infer_objects().dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %% [markdown]
# But objects are a standard type to store strings, therefore nothing happens.
#
# __Digression__
#
# We have different attributes associated with each object, we can assess that by three main ways
# 1. `dir()`
# 2. `vars()`
# 3. `.__dict__` could be equivalent to `vars()`

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...

# %% [markdown]
# Yeah it works for modules as well.

# %%
pd.__dict__
# Out:
# {'__name__': 'pandas',
# ...

# %%
vars(pd) == pd.__dict__
# Out:
# True

# %% [markdown]
# Such conditional statement verifies the provided information that vars corresponds to .__dict__, at least on this specific case.
#
# This could be of interest if one desires to see the attributes.

# %%
dir(df)
# Out:
# ['Age',
#  'City_Category',
#  'Gender',
#  'Marital_Status',
#  'Occupation',
#  'Product_Category_1',
#  'Product_Category_2',
#  'Product_Category_3',
#  'Product_ID',
#  'Purchase',
#  'Stay_In_Current_City_Years',
#  'T',
#  'User_ID',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
# ...

# %% [markdown]
# As we can see the pandas provides a lot of tools to manipulate the dataframe.

# %%
dir(df.dtypes)
# Out:
# ['Age',
#  'City_Category',
#  'Gender',
#  'Marital_Status',
#  'Occupation',
#  'Product_Category_1',
#  'Product_Category_2',
#  'Product_Category_3',
#  'Product_ID',
#  'Purchase',
#  'Stay_In_Current_City_Years',
#  'T',
#  'User_ID',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
# ...

# %% [markdown]
# You can see that by yourself. Let's look at the first row. Yes. Again the first row.

# %%
df.head(1)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370

# %% [markdown]
# Wait. Python starts at 0 remember?

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [User_ID, Product_ID, Gender, Age, Occupation, City_Category, Stay_In_Current_City_Years, Marital_Status, Product_Category_1, Product_Category_2, Product_Category_3, Purchase]
# Index: []

# %% [markdown]
# Oh you got me.
#
# But head doesn't ...

# %%
df.head(1)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370

# %% [markdown]
# We have different ways to access the data:
#
# #### [iloc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html)

# %%
df.iloc[[0,]]
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370

# %% [markdown]
# Now starts with 0.
#
# 1. First argument corresponds to line number
# 2. Second one to column number
#
# Why so many brackets?
#
# To keep a dataframe structure.
#
# As you can see

# %%
df.iloc[0,]
# Out:
# User_ID                         1000001
# Product_ID                    P00069042
# Gender                                F
# Age                                0-17
# Occupation                           10
# City_Category                         A
# Stay_In_Current_City_Years            2
# Marital_Status                        0
# Product_Category_1                    3
# Product_Category_2                  NaN
# Product_Category_3                  NaN
# Purchase                           8370
# Name: 0, dtype: object

# %%
df.iloc[[True,]]
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370

# %% [markdown]
# #### [loc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html)
# In this particular case the both functions correspond when one performs linewise operations.
#
# That occurs because the automatically created index row, which corresponds to the line label, follows the natural way to count from Python.

# %%
df.loc[[0,]]
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370

# %%
df.iloc[[0]]
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370

# %% [markdown]
# We have a lot of ways to get a single element.

# %%
df.Product_ID[0]
# Out:
# 'P00069042'

# %%
df.Product_ID.loc[0]
# Out:
# 'P00069042'

# %%
df.Product_ID.iloc[0]
# Out:
# 'P00069042'

# %%
df['Product_ID'].loc[0]
# Out:
# 'P00069042'

# %%
df['Product_ID'].iloc[0]
# Out:
# 'P00069042'

# %%
df.iloc[0,1]
# Out:
# 'P00069042'

# %%
df.iloc[0].iloc[1]
# Out:
# 'P00069042'

# %%
df.loc[0,'Product_ID']
# Out:
# 'P00069042'

# %%
df.loc[0].Product_ID
# Out:
# 'P00069042'

# %%
df.loc[0]['Product_ID']
# Out:
# 'P00069042'

# %% [markdown]
# Avoid that is not a good practice and can conduct to mistakes when we have brackets that close and open in a sequence `][`.
#
# We have sufficient ways to call the same datapoint. Don't need to do that.

# %%
df.loc[0].loc['Product_ID']
# Out:
# 'P00069042'

# %%
df.loc[0].iloc[1]
# Out:
# 'P00069042'

# %% [markdown]
# But keep on mind that if we use only one index that refers to lines.

# %%
df.iloc[1].iloc[0]
# Out:
# 1000001

# %% [markdown]
# That is in the dataframe select the second line (starts on 0) and then the first element.
#
# As you can confirm that by looking at the data.

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %% [markdown]
# But we could be on the first element from the first line.
#
# Because they refer to the same User_ID.
#
# And I'm not convinced about it.
#
# 1. That makes no sense. Because we retrieve differente indexes 1 and 0. So it can't be first and first.
# 2. But let's look the element to the right (the second, second)

# %%
df.iloc[1].iloc[1]
# Out:
# 'P00248942'

# %% [markdown]
# Oh good.
#
# We haven't look at it never before.
#
# Case closed.

# %% [markdown]
# So, now we are able to access elements, and so can talk about the strings stored on objects, remember?

# %%
df.Product_ID[0]
# Out:
# 'P00069042'

# %% [markdown]
# Seriously? We have ... wait for it ...

# %%
df.size
# Out:
# 6450924

# %% [markdown]
# 6,450,924 datapoints ...
#
# What 6.5 millions???
#
# Anyway, and this element was called again?
# Be more creative.

# %%
df.Gender[0]
# Out:
# 'F'

# %%
df.Age[0]
# Out:
# '0-17'

# %%
df.City_Category[0]
# Out:
# 'A'

# %%
df.Stay_In_Current_City_Years[0]
# Out:
# '2'

# %%
type(df.Product_ID[0])
# Out:
# str

# %%
type(df.Gender[0])
# Out:
# str

# %%
type(df.Age[0])
# Out:
# str

# %%
type(df.City_Category[0])
# Out:
# str

# %%
type(df.Stay_In_Current_City_Years[0])
# Out:
# str

# %% [markdown]
# To access the memoty usage on bits:

# %%
df.memory_usage()
# Out:
# Index                              80
# User_ID                       4300616
# Product_ID                    4300616
# Gender                        4300616
# Age                           4300616
# Occupation                    4300616
# City_Category                 4300616
# Stay_In_Current_City_Years    4300616
# Marital_Status                4300616
# Product_Category_1            4300616
# Product_Category_2            4300616
# Product_Category_3            4300616
# Purchase                      4300616
# dtype: int64

# %%
df.memory_usage().sum()
# Out:
# 51607472

# %% [markdown]
# So in MB or MegaBytes:

# %%
df.memory_usage().sum() / (1024**2)
# Out:
# 49.21672058105469

# %%
df.index
# Out:
# RangeIndex(start=0, stop=537577, step=1)

# %% [markdown]
# The not null data are missing.
#
# To assess how many by the step by step approach.
#
# We use a boolean dataframe

# %%
df.notnull()
# Out:
#         User_ID  Product_ID  Gender   Age  Occupation  City_Category  \
# 0          True        True    True  True        True           True
# 1          True        True    True  True        True           True
# 2          True        True    True  True        True           True
# 3          True        True    True  True        True           True
# 4          True        True    True  True        True           True
# 5          True        True    True  True        True           True
# 6          True        True    True  True        True           True
# 7          True        True    True  True        True           True
# 8          True        True    True  True        True           True
# 9          True        True    True  True        True           True
# 10         True        True    True  True        True           True
# 11         True        True    True  True        True           True
# 12         True        True    True  True        True           True
# ...

# %% [markdown]
# and sum up it on the vertical direction (axis 0, the default one).

# %%
df.notnull().sum()
# Out:
# User_ID                       537577
# Product_ID                    537577
# Gender                        537577
# Age                           537577
# Occupation                    537577
# City_Category                 537577
# Stay_In_Current_City_Years    537577
# Marital_Status                537577
# Product_Category_1            537577
# Product_Category_2            370591
# Product_Category_3            164278
# Purchase                      537577
# dtype: int64

# %% [markdown]
# or we can use the equivalent `notna()`

# %%
df.notna().sum()
# Out:
# User_ID                       537577
# Product_ID                    537577
# Gender                        537577
# Age                           537577
# Occupation                    537577
# City_Category                 537577
# Stay_In_Current_City_Years    537577
# Marital_Status                537577
# Product_Category_1            537577
# Product_Category_2            370591
# Product_Category_3            164278
# Purchase                      537577
# dtype: int64

# %%
df.notna().sum().sum() == df.notnull().sum().sum()
# Out:
# True

# %% [markdown]
# So now we have all the information provided by the direct way

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
# User_ID                       537577 non-null int64
# Product_ID                    537577 non-null object
# Gender                        537577 non-null object
# Age                           537577 non-null object
# Occupation                    537577 non-null int64
# City_Category                 537577 non-null object
# Stay_In_Current_City_Years    537577 non-null object
# Marital_Status                537577 non-null int64
# Product_Category_1            537577 non-null int64
# Product_Category_2            370591 non-null float64
# Product_Category_3            164278 non-null float64
# Purchase                      537577 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 49.2+ MB

# %% [markdown]
# And how many unique values we have?

# %%
df.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3623
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               18
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      17959
# dtype: int64

# %% [markdown]
# From some categories we have little options, let's see which labels do we have for them.
#
# As observable, such columns range from Gender to Product_Category_3. Let's slice our dataframe.

# %%
df.loc[:,'Gender':'Product_Category_3']
# Out:
#        Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F   0-17          10             A                          2
# 1           F   0-17          10             A                          2
# 2           F   0-17          10             A                          2
# 3           F   0-17          10             A                          2
# 4           M    55+          16             C                         4+
# 5           M  26-35          15             A                          3
# 6           M  46-50           7             B                          2
# 7           M  46-50           7             B                          2
# 8           M  46-50           7             B                          2
# 9           M  26-35          20             A                          1
# 10          M  26-35          20             A                          1
# 11          M  26-35          20             A                          1
# ...

# %% [markdown]
# A long time ago in an early age, we see how to count the values, remember?

# %%
df.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# dtype: int64

# %%
df.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-256-986e25863b45> in <module>
# ----> 1 df.value_counts()
#
# c:\users\fuck\pycharmprojects\codenation\venv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# We can do that for Series, but not for DataFrames ...
#
# Case closed. Life goes on...
#
# No wait there a lot of trick things, one of them is mapping.
#
# We can apply it. Sorry that was too forced.

# %%
df.apply?

# %% [markdown]
# Ok, apply is a method that enables us to apply some function suitable to Series on DataFrames.
#
# Oh, yeah that's what we need, don't we?
#
# But how to create a function on Python?
#
# The standard way is with `def():`.
#
# But we have another option, we can use lambda functions.
#
# So we are already confused, and you talk on Greek. Easy now.

# %%
add_one = lambda x: x+1
print(add_one(5))
# Out:
# 6

# %% [markdown]
# So we create a function to adds one and that's totally ... unuseful.
#
# But we could understand the idea.
#
# So are you telling us that that's lambda function.
#
# I don't trust you. You've got me on the head thing.
#
# So check.

# %%
type(lambda x: x+1)
# Out:
# function

# %% [markdown]
# Checkmate!
#
# It's indeed a function.
#
# So let's do it.

# %%
df.loc[:,'Gender':'Product_Category_3'].apply(lambda x: x.value_counts())
# Out:
#          Gender       Age  Occupation  City_Category  \
# 0           NaN       NaN     68120.0            NaN
# 1           NaN       NaN     45971.0            NaN
# 2           NaN       NaN     25845.0            NaN
# 3           NaN       NaN     17366.0            NaN
# 4           NaN       NaN     70862.0            NaN
# 5           NaN       NaN     11985.0            NaN
# 6           NaN       NaN     19822.0            NaN
# 7           NaN       NaN     57806.0            NaN
# 8           NaN       NaN      1524.0            NaN
# 9           NaN       NaN      6153.0            NaN
# 10          NaN       NaN     12623.0            NaN
# 11          NaN       NaN     11338.0            NaN
# 12          NaN       NaN     30423.0            NaN
# 13          NaN       NaN      7548.0            NaN
# 14          NaN       NaN     26712.0            NaN
# 15          NaN       NaN     11812.0            NaN
# 16          NaN       NaN     24790.0            NaN
# ...

# %% [markdown]
# No, no, no. All that text to do that. We can interpret it.
#
# It's a dataframe with no data.
#
# So let's try to transform it a little.

# %%
df.T
# Out:
#                                0          1          2          3       \
# User_ID                       1000001    1000001    1000001    1000001
# Product_ID                  P00069042  P00248942  P00087842  P00085442
# Gender                              F          F          F          F
# Age                              0-17       0-17       0-17       0-17
# Occupation                         10         10         10         10
# City_Category                       A          A          A          A
# Stay_In_Current_City_Years          2          2          2          2
# Marital_Status                      0          0          0          0
# Product_Category_1                  3          1         12         12
# Product_Category_2                NaN          6        NaN         14
# Product_Category_3                NaN         14        NaN        NaN
# Purchase                         8370      15200       1422       1057
#
# ...

# %% [markdown]
# Not again, we only transpose the data frame. And that's not helpful.
#
# Let's try another way, let's stack the data.

# %%
df.stack()
# Out:
# 0       User_ID                         1000001
#         Product_ID                    P00069042
#         Gender                                F
#         Age                                0-17
#         Occupation                           10
#         City_Category                         A
#         Stay_In_Current_City_Years            2
#         Marital_Status                        0
#         Product_Category_1                    3
#         Purchase                           8370
# 1       User_ID                         1000001
#         Product_ID                    P00248942
#         Gender                                F
#         Age                                0-17
#         Occupation                           10
#         City_Category                         A
#         Stay_In_Current_City_Years            2
#         Marital_Status                        0
#         Product_Category_1                    1
#         Product_Category_2                    6
# ...

# %% [markdown]
# You can't be serious, we have a well structured dataframe. And you do that? What for?

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %% [markdown]
# Just by tranposing our visualization improved a little.

# %%
df.loc[:,'Gender':'Product_Category_3'].apply(lambda x: x.value_counts()).T
# Out:
#                                    0         1        2        3        4  \
# Gender                           NaN       NaN      NaN      NaN      NaN
# Age                              NaN       NaN      NaN      NaN      NaN
# Occupation                   68120.0   45971.0  25845.0  17366.0  70862.0
# City_Category                    NaN       NaN      NaN      NaN      NaN
# Stay_In_Current_City_Years       NaN       NaN      NaN      NaN      NaN
# Marital_Status              317817.0  219760.0      NaN      NaN      NaN
# Product_Category_1               NaN  138353.0  23499.0  19849.0  11567.0
# Product_Category_2               NaN       NaN  48481.0   2835.0  25225.0
# Product_Category_3               NaN       NaN      NaN    600.0   1840.0
#
#                                    5        6        7         8        9  \
# Gender                           NaN      NaN      NaN       NaN      NaN
# Age                              NaN      NaN      NaN       NaN      NaN
# ...

# %% [markdown]
# Let's try to put it _alltogether_.

# %%
df.loc[:,'Gender':'Product_Category_3'].apply(lambda x: x.value_counts()).T.stack()
# Out:
# Gender              F        132197.0
#                     M        405380.0
# Age                 0-17      14707.0
#                     18-25     97634.0
#                     26-35    214690.0
#                     36-45    107499.0
#                     46-50     44526.0
#                     51-55     37618.0
#                     55+       20903.0
# Occupation          0         68120.0
#                     1         45971.0
#                     2         25845.0
#                     3         17366.0
#                     4         70862.0
#                     5         11985.0
#                     6         19822.0
#                     7         57806.0
#                     8          1524.0
#                     9          6153.0
#                     10        12623.0
#                     11        11338.0
#                     12        30423.0
#                     13         7548.0
#                     14        26712.0
#                     15        11812.0
# ...

# %% [markdown]
# Oh stack is useful when you have no data and a well-known structured.
#
# If we have no data, we do nothing.
#
# Yeah, thanks, when we have a lot of missing data.
#
# Talking on missing, and this ... thing before Product_Category_2?
#
# Our display is truncated to improve the visualization.
#
# Normally that's good.
#
# Now it wasn't.
#
# We can print to avoid that.

# %%
print(df.loc[:,'Gender':'Product_Category_3'].apply(lambda x: x.value_counts()).T.stack())
# Out:
# Gender              F        132197.0
#                     M        405380.0
# Age                 0-17      14707.0
#                     18-25     97634.0
#                     26-35    214690.0
#                     36-45    107499.0
#                     46-50     44526.0
#                     51-55     37618.0
#                     55+       20903.0
# Occupation          0         68120.0
#                     1         45971.0
#                     2         25845.0
#                     3         17366.0
#                     4         70862.0
#                     5         11985.0
#                     6         19822.0
#                     7         57806.0
#                     8          1524.0
#                     9          6153.0
#                     10        12623.0
#                     11        11338.0
#                     12        30423.0
#                     13         7548.0
#                     14        26712.0
#                     15        11812.0
# ...

# %% [markdown]
# We avoid nothing man. The lines are still missing.
#
# Oh yeah. It was detected as a dataframe and truncated for us.
#
# If it would be not a dataframe, perhaps convert it to string?

# %%
print(df.loc[:,'Gender':'Product_Category_3'].apply(lambda x: x.value_counts()).T.stack().to_string())
# Out:
# Gender                      F        132197.0
#                             M        405380.0
# Age                         0-17      14707.0
#                             18-25     97634.0
#                             26-35    214690.0
#                             36-45    107499.0
#                             46-50     44526.0
#                             51-55     37618.0
#                             55+       20903.0
# Occupation                  0         68120.0
#                             1         45971.0
#                             2         25845.0
#                             3         17366.0
#                             4         70862.0
#                             5         11985.0
#                             6         19822.0
#                             7         57806.0
#                             8          1524.0
#                             9          6153.0
#                             10        12623.0
# ...

# %% [markdown]
# We got that.
#
# Are you kidding me? 102 characters in a single line. The PEP8 won't take that well.
#
# The PEP8 are a guidebook for best programming practice on Python.
#
# We are encouraged to internalize it, but it takes time.
#
# I'm just starting on this data scientist life as well, so you will see a lot of imprecisions by my part. Sorry.

# %%
print(df
      .loc[:,'Gender':'Product_Category_3']
      .apply(lambda x: x.value_counts())
      .T
      .stack()
      .to_string()
     )
# Out:
# Gender                      F        132197.0
#                             M        405380.0
# Age                         0-17      14707.0
#                             18-25     97634.0
#                             26-35    214690.0
#                             36-45    107499.0
#                             46-50     44526.0
#                             51-55     37618.0
#                             55+       20903.0
# Occupation                  0         68120.0
#                             1         45971.0
#                             2         25845.0
#                             3         17366.0
#                             4         70862.0
#                             5         11985.0
#                             6         19822.0
#                             7         57806.0
#                             8          1524.0
#                             9          6153.0
#                             10        12623.0
# ...

# %% [markdown]
# Much more readable. And does the same.

# %%
df.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3623
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               18
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      17959
# dtype: int64

# %%
df.shape
# Out:
# (537577, 12)

# %% [markdown]
# Looking at this Black Friday Dataset, we observe
# 1. 5,891 user's ID were used to acquire 537,577 products
# 2. Among them are 3,623 different products
# 3. 2 Genders: F and M
# 4. 7 Age Ranges: 0-17, 18-25, 26-35, 36-45, 46-50, 51-55, 55+
# 5. 21 Ocupations: range from 0 to 20
# 6. 3 City Categories: A, B, C
# 7. 5 Stay in Current City Years Categories: 0, 1, 2, 3, 4+
# 8. 2 Marital Status: 0 and 1
# 9. 18 Product Category 1: range from 1 to 18
# 10. 17 Product Category 2: range from 2 to 18
# 11. 15 Product Category 3: range from 3 to 6 and from 8 to 18
# 12. 17,959 different purchase values

# %% [markdown]
# ### Describe the data

# %% [markdown]
# In order to describe the data we can

# %%
df.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# ...

# %% [markdown]
# Oh wait! 7 columns? But for now we know by heart that we have 12 columns...

# %%
len(df.describe().columns)
# Out:
# 7

# %% [markdown]
# And the object type columns? Let's select them

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'City_Category',
#        'Stay_In_Current_City_Years'],
#       dtype='object')

# %% [markdown]
# [`select_dtypes`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.select_dtypes.html)

# %%
df.select_dtypes(exclude=['object']).columns
# Out:
# Index(['User_ID', 'Occupation', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df.describe().columns == df.select_dtypes(exclude=['object']).columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# So this procedure can summarize the numerical columns. It doesn't operate on strings.
#
# As at first impression, makes little sense to talk about statistics on categorical data.

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.pairplot(df)
plt.show()

# %%
df.query?

# %% [markdown]
# ## By incidence
#
# The following analyses have an y-axis that accounts for each single purchase.

# %%
df['Age'].value_counts().sort_index().plot(kind='bar', title = 'Purchases by Age Range');

# %%
df['Gender'].value_counts().sort_index().plot(kind='bar');

# %%
df['City_Category'].value_counts().sort_index().plot(kind='bar');

# %%
df['Stay_In_Current_City_Years'].value_counts().sort_index().plot(kind='bar');

# %%
#df['Product_ID'].value_counts().sort_index().plot(kind='bar');

# %%
sns.countplot(x='Age', order=sorted(df['Age'].unique()), hue='Gender', data=df);

# %% [markdown]
# As we can see from our preconceived chauvinist opinion the women buy much more anywhen, like the histogram ...
#
# Oh no. So bring me the data!
#
# In this dataset the men buy more.
#
# So avoid any unbased idea not only in our analyses, but in the life per se.

# %%
sns.countplot(x='Age', order=sorted(df['Age'].unique()), hue='Marital_Status', data=df);

# %% [markdown]
# As we can see no person below 17 has `Marital_Status` 1.
#
# So let's say that's much more probable that 0 means single and 1 means married.

# %% [markdown]
# It seems that this data from object columns, contains a lot of information.
# So let's modify those data on our dataframe and ...
#
# > Noooooooooooooooooooooo
#
# Wait...
#
# It's not good practice to alter the original dataset, remember?
#
# Oh yeah. What can we do?
#
# Perhaps we can create a new dataset converting such data on numerical ones.
#
# To avoid any association betwenn df and df2 (the new dataframe), let's import again from the original data.

# %%
df2 = pd.read_csv("black_friday.csv")

# %% [markdown]
# Ok, so what columns do we have to change?
#
# Oh yeah they with object type.

# %%
df2.select_dtypes(include=['object']).columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'City_Category',
#        'Stay_In_Current_City_Years'],
#       dtype='object')

# %% [markdown]
# We could see which values appear in a column as
#
# (Dejavu)

# %%
df2['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %% [markdown]
# Perhaps it would be interesting to sort the labels

# %%
np.sort(df[column].unique())
# Out:
# array(['0-17', '18-25', '26-35', '36-45', '46-50', '51-55', '55+'],
#       dtype=object)

# %% [markdown]
# To count how many different categories do we have, we see the length of such np.array

# %%
len(np.sort(df[column].unique()))
# Out:
# 7

# %% [markdown]
# A naive approach, could be create labels ranging from 0 to its len units.

# %%
np.arange(len(np.sort(df[column].unique())))
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %% [markdown]
# So we have to replace them and that's it

# %%
column = 'Age'
unique_values = np.sort(df2[column].unique())
repl = unique_values
vl = np.arange(len(unique_values))
df2[column].replace(to_replace = repl,
                        value = vl,
                        inplace = True)
df2[column].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    6
# Name: Age, dtype: int64

# %% [markdown]
# It seems to have worked ...

# %%
df2[column].value_counts().sort_index()
# Out:
# 0     14707
# 1     97634
# 2    214690
# 3    107499
# 4     44526
# 5     37618
# 6     20903
# Name: Age, dtype: int64

# %%
df[column].value_counts().sort_index()
# Out:
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# Name: Age, dtype: int64

# %% [markdown]
# It worked!
#
# Now we have only 4 more let's do for each

# %%
for column in df2.select_dtypes(include=['object']).columns:
    unique_values = np.sort(df2[column].unique())
    df2[column].replace(to_replace = unique_values,
                        value = np.arange(len(unique_values)),
                        inplace = True)

# %% [markdown]
# Don't worry it takes a while. We are replacing ...

# %%
(len(df.select_dtypes(include=['object']).columns) - 1) * df2.shape[0]
# Out:
# 2687885

# %% [markdown]
# 2,687,885 elements, because we've already replaced the Age column.
#
# One way to look at the previous names of the variables is by means of a dataframe created from a dictionary.

# %%
dic_old_names = {column : np.sort(df[column].unique()).tolist() for column in df.select_dtypes(include=['object']).columns}

# %%
df_old_names = pd.DataFrame.from_dict(dic_old_names, orient='index')
df_old_names
# Out:
#                                  0          1          2          3     \
# Product_ID                  P00000142  P00000242  P00000342  P00000442
# Gender                              F          M       None       None
# Age                              0-17      18-25      26-35      36-45
# City_Category                       A          B          C       None
# Stay_In_Current_City_Years          0          1          2          3
#
#                                  4          5          6          7     \
# Product_ID                  P00000542  P00000642  P00000742  P00000842
# Gender                           None       None       None       None
# Age                             46-50      51-55        55+       None
# City_Category                    None       None       None       None
# Stay_In_Current_City_Years         4+       None       None       None
#
#                                  8          9     ...      3613      3614  \
# ...

# %%
df2.describe()
# Out:
#             User_ID     Product_ID         Gender            Age  \
# count  5.375770e+05  537577.000000  537577.000000  537577.000000
# mean   1.002992e+06    1692.331275       0.754087       2.494755
# std    1.714393e+03    1002.576538       0.430627       1.352583
# min    1.000001e+06       0.000000       0.000000       0.000000
# 25%    1.001495e+06     927.000000       1.000000       2.000000
# 50%    1.003031e+06    1646.000000       1.000000       2.000000
# 75%    1.004417e+06    2534.000000       1.000000       3.000000
# max    1.006040e+06    3622.000000       1.000000       6.000000
#
#          Occupation  City_Category  Stay_In_Current_City_Years  \
# count  537577.00000  537577.000000               537577.000000
# mean        8.08271       1.040567                    1.859458
# std         6.52412       0.759627                    1.289828
# min         0.00000       0.000000                    0.000000
# ...

# %%
sns.pairplot(df2)
plt.show()

# %%
np.arange(2)
# Out:
# array([0, 1])

# %%
df[(df.Gender == 'F') & (df.Age == '26-35')].count().User_ID.item()
# Out:
# 49348

# %%
lines_na = df.isna().sum(axis=1) > 0

# %%
len(df[(df.Gender == 'F') & (df.Age == '26-35')])
# Out:
# 49348

# %%
filter = ['Gender','Age','User_ID']
group = ['Gender','Age']
match = ['F', '36-45']
aux = df[filter].groupby(group).count()
df[filter].groupby(group).count()

# %%
df[(df.Gender == 'F') & (df.Age == '26-35')].count().User_ID

# %%
type(df[(df.Gender == 'F') & (df.Age == '26-35')].count().User_ID)

# %%
df.isna().sum(axis=1)

# %%
(df.isna().sum(axis=1) > 0) / df.shape[0]

# %%
df.isna().sum(axis=1) > 0

# %%
lines_na = df.isna().sum(axis=1) > 0
lines_na.mean()

# %%
col_na = df.isna().sum().max()
col_na

# %%
df.isna().sum()

# %%
filtered_df = df[df['Age'].notnull()]
filtered_df

# %%
filtered_df = df[df[df.columns].notnull().all(1)]
filtered_df

# %%
df.Product_Category_3.mode()

# %%
df.mode()

# %%
df.Product_Category_3.mode().values[0]

# %%
def padronizar(x):
    z = ( x - x.mean() ) / x.std()
    return z

# %%
x = [1,2]
padronizar(df.Purchase.to_numpy())

# %%
padronizar(df.Purchase.to_numpy()).mean()

# %%
x = df.Purchase.to_numpy()
z = ( x - x.mean() ) / x.std()
z.mean()

# %%
x = df.Purchase.to_numpy()
x_normal = ( x - x.min() ) / ( x.max() - x.min() )
v_bool = (x_normal >= -1.0) & (x_normal <= 1.0)
v_bool.sum()

# %%
(df['Product_Category_3']
 .loc[df['Product_Category_2'].isna()]
 .notna().any() == False
)
# Out:
# True

# %%
data = {'Product_Category_2': [np.nan, 2, np.nan, 0], 'Product_Category_3': [np.nan, 'b', 'c', 'd']}
dft = pd.DataFrame.from_dict(data)
(dft['Product_Category_3']
 .loc[dft['Product_Category_2'].isna()]
 .isna().all() == True
)
# Out:
# False

# %%
a = np.random.rand(10 ** 5, 5)
df1 = pd.DataFrame(a)
row = 50_000
col = 3

# %%
# %timeit df1.iloc[row, col]
# Out:
# 18.1 µs ± 324 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit a[row, col]
# Out:
# 323 ns ± 3.12 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit df1.to_numpy()
# Out:
# 15.7 µs ± 98.2 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ## Inicie sua análise a partir daqui

# %% [markdown]
# ## Questão 1
#
# Quantas observações e quantas colunas há no dataset? Responda no formato de uma tuple `(n_observacoes, n_colunas)`.

# %%
def q1():
    return df.shape

# %% [markdown]
# ## Questão 2
#
# Há quantas mulheres com idade entre 26 e 35 anos no dataset? Responda como um único escalar.

# %%
def q2():
    return len(
        df[
            (df['Gender'] == 'F')
            & (df['Age'] == '26-35')
        ]
    )

# %% [markdown]
# ## Questão 3
#
# Quantos usuários únicos há no dataset? Responda como um único escalar.

# %%
def q3():
    return (
        df['User_ID']
        .nunique()
    )

# %% [markdown]
# ## Questão 4
#
# Quantos tipos de dados diferentes existem no dataset? Responda como um único escalar.

# %%
def q4():
    return (
        df
        .dtypes
        .nunique()
    )

# %% [markdown]
# ## Questão 5
#
# Qual porcentagem dos registros possui ao menos um valor null (`None`, `ǸaN` etc)? Responda como um único escalar entre 0 e 1.

# %%
def q5():
    na_lines = (
        df
        .isna()
        .sum(axis=1)
        > 0
    )
    return (
        lines_na
        .mean()
        .item()
    )

# %% [markdown]
# ## Questão 6
#
# Quantos valores null existem na variável (coluna) com o maior número de null? Responda como um único escalar.

# %%
def q6():
    return (
        df
        .isna()
        .sum()
        .max()
        .item()
    )

# %% [markdown]
# ## Questão 7
#
# Qual o valor mais frequente (sem contar nulls) em `Product_Category_3`? Responda como um único escalar.

# %%
def q7():
    return (
        df['Product_Category_3']
        .mode()
        .item()
    )

# %% [markdown]
# ## Questão 8
#
# Qual a nova média da variável (coluna) `Purchase` após sua normalização? Responda como um único escalar.

# %%
def q8():
    x = df['Purchase'].to_numpy()
    
    x_mod = (x - x.min()) / (x.max() - x.min())
    
    return (
        x_mod
        .mean()
        .item()
    )

# %% [markdown]
# ## Questão 9
#
# Quantas ocorrências entre -1 e 1 inclusive existem da variável `Purchase` após sua padronização? Responda como um único escalar.

# %%
def q9():
    x = df['Purchase'].to_numpy()
    
    z = (x - x.mean()) / x.std()
    
    v_bool = (z >= -1.0) & (z <= 1.0)
    
    return (
        v_bool
        .sum()
        .item()
    )

# %% [markdown]
# ## Questão 10
#
# Podemos afirmar que se uma observação é null em `Product_Category_2` ela também o é em `Product_Category_3`? Responda com um bool (`True`, `False`).

# %%
def q10():
    return (
        df['Product_Category_3']
        .loc[df['Product_Category_2'].isnull()]
        .isnull().all() == True
    )

# %% [markdown]
# ## Chamando as funções

# %%
q1()

# %%
q2()

# %%
q3()

# %%
q4()

# %%
q5()

# %%
q6()

# %%
q7()

# %%
q8()

# %%
q9()

# %%
q10()
