# %% [markdown]
# Streamlit
#
# 02/07/2020
#
# AceleraDev Data Science Codenation, segunda semana

# %%
#!pip install streamlit
import streamlit as st

# %%
st.title("Hello World!")

# %%
# Out:
#   File "<ipython-input-5-0c4a1463ea42>", line 1
#     streamlit run st.title("Hello World!")
#                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
